# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("healthexp.csv", delimiter=",")

# %%
data
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 273  2020        Germany      6938.983             81.1
# 274  2020         France      5468.418             82.3
# 275  2020  Great Britain      5018.700             80.4
# 276  2020          Japan      4665.641             84.7
# 277  2020            USA     11859.179             77.0
#
# [278 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             278 non-null    int64
#  1   Country          278 non-null    object
#  2   Spending_USD     278 non-null    float64
#  3   Life_Expectancy  278 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 8.8+ KB

# %%
data.describe()
# Out:
#               Year  Spending_USD  Life_Expectancy
# count   278.000000    278.000000       278.000000
# mean   1996.974820   2777.484824        77.905396
# std      14.081355   2185.541179         3.259057
# min    1970.000000    123.993000        70.600000
# 25%    1986.000000   1038.357000        75.600000
# 50%    1997.000000   2282.865000        78.100000
# 75%    2009.000000   4026.490000        80.500000
# max    2020.000000  11859.179000        84.700000

# %%
data = pd.read_csv('healthexp.csv', header=None, error_bad_lines=False)
print(data.shape)
# Out:
# (279, 4)

# %%
data =  pd.read_csv('healthexp.csv',header=None)
print(data.shape)
counts = data.nunique()
to_del = [i for i, v in enumerate(counts) if v==1]
print(to_del)
data.drop(data.columns[to_del], axis=1, inplace=True)
print(data.shape)
# Out:
# (279, 4)
# []
# (279, 4)

# %%
dups = data.duplicated()
print(dups)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 274    False
# 275    False
# 276    False
# 277    False
# 278    False
# Length: 279, dtype: bool

# %%
data.drop_duplicates(inplace=True)
print(data.shape)
# Out:
# (275, 4)

# %%
import pandas as pd
data = pd.read_csv('healthexp.csv',delimiter=',')
data
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 273  2020        Germany      6938.983             81.1
# 274  2020         France      5468.418             82.3
# 275  2020  Great Britain      5018.700             80.4
# 276  2020          Japan      4665.641             84.7
# 277  2020            USA     11859.179             77.0
#
# [278 rows x 4 columns]

# %%
plt.figure(figsize=(8,5))
plt.scatter(data['Spending_USD'], data['Life_Expectancy'], c='red', marker='x',alpha=0.5)
plt.xlabel('Spending_(USD)')
plt.ylabel('Life Expectancy')
plt.title('Spending vs Life Expectancy')
plt.show()

# %%
plt.figure(figsize=(8,5))
scatter = plt.scatter(data['Spending_USD'], data['Life_Expectancy'], 
                      c=data['Life_Expectancy'], s=50)
plt.xlabel('Spending (USD)')
plt.ylabel('Life Expectancy')
plt.title('Spending vs Life Expectancy')
plt.colorbar(scatter, label='Life Expectancy')
plt.show()

# %%
columns = data.columns.drop(['Life_Expectancy'])
x_data = range(0 , data.shape[0])
fig, ax = plt.subplots()
for column in columns:
    ax.plot(x_data, data[column], label = column)
ax.set_title('data Dataset')
ax.legend()

# %%
plt.figure(figsize=(6,4))
plt.hist(data['Life_Expectancy'], color='skyblue', edgecolor='black')
plt.title('Distribution of Life Expectancy')
plt.xlabel('Life Expectancy')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
data = pd.read_csv('healthexp.csv',delimiter=',')
data
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 273  2020        Germany      6938.983             81.1
# 274  2020         France      5468.418             82.3
# 275  2020  Great Britain      5018.700             80.4
# 276  2020          Japan      4665.641             84.7
# 277  2020            USA     11859.179             77.0
#
# [278 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
points_count = data['Country'].value_counts()
points = points_count.index
frequency = points_count.values
colors = ['skyblue', 'orange', 'green', 'red', 'purple', 'yellow', 'pink']

plt.figure(figsize=(8,4))
plt.bar(points, frequency, color=colors[:len(points)])  
plt.title('Frequency of Countries in Dataset')
plt.xlabel('Country')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# seperate them into X and y
X = data[['Year','Country','Spending_USD']].values
X
# Out:
# array([[1970, 'Germany', 252.31099999999998],
#        [1970, 'France', 192.143],
#        [1970, 'Great Britain', 123.993],
#        [1970, 'Japan', 150.437],
#        [1970, 'USA', 326.961],
#        [1971, 'Canada', 313.39099999999996],
#        [1971, 'Germany', 298.251],
#        [1971, 'Great Britain', 134.172],
#        [1971, 'Japan', 163.854],
#        [1971, 'USA', 357.98800000000006],
#        [1972, 'Germany', 337.36400000000003],
#        [1972, 'Japan', 185.39],
#        [1972, 'USA', 397.097],
#        [1973, 'Germany', 384.541],
#        [1973, 'Japan', 205.778],
#        [1973, 'USA', 439.30199999999996],
#        [1974, 'Germany', 452.744],
#        [1974, 'Japan', 242.018],
#        [1974, 'USA', 495.11400000000003],
#        [1975, 'Germany', 532.481],
#        [1975, 'France', 363.61],
#        [1975, 'Japan', 284.269],
#        [1975, 'USA', 560.75],
#        [1976, 'Canada', 543.337],
#        [1976, 'Germany', 591.0980000000001],
# ...

# %%
y = data[['Life_Expectancy']].values
y
# Out:
# array([[70.6],
#        [72.2],
#        [71.9],
#        [72. ],
#        [70.9],
#        [72.8],
#        [70.8],
#        [71.9],
#        [72.9],
#        [71.2],
#        [71. ],
#        [73.2],
#        [71.2],
#        [71.3],
#        [73.4],
#        [71.4],
#        [71.5],
#        [73.7],
#        [72. ],
#        [71.4],
#        [73. ],
#        [74.3],
#        [72.7],
#        [73.8],
#        [71.8],
#        [74.8],
#        [72.9],
#        [72.5],
#        [75.3],
#        [73.3],
#        [72.4],
#        [75.7],
#        [73.5],
#        [75.1],
#        [72.8],
#        [76.2],
#        [73.9],
#        [75.2],
#        [72.9],
#        [74.3],
#        [73.2],
#        [76.1],
#        [73.7],
#        [75.5],
#        [73.2],
#        [73.8],
#        [76.5],
#        [74.1],
#        [75.6],
#        [73.5],
#        [74.1],
#        [76.9],
#        [74.5],
#        [75.9],
#        [73.8],
#        [74.3],
#        [77. ],
#        [74.6],
# ...

# %%
import numpy as np

# %%
X = data[['Year','Spending_USD']].values
X
# Out:
# array([[ 1970.   ,   252.311],
#        [ 1970.   ,   192.143],
#        [ 1970.   ,   123.993],
#        [ 1970.   ,   150.437],
#        [ 1970.   ,   326.961],
#        [ 1971.   ,   313.391],
#        [ 1971.   ,   298.251],
#        [ 1971.   ,   134.172],
#        [ 1971.   ,   163.854],
#        [ 1971.   ,   357.988],
#        [ 1972.   ,   337.364],
#        [ 1972.   ,   185.39 ],
#        [ 1972.   ,   397.097],
#        [ 1973.   ,   384.541],
#        [ 1973.   ,   205.778],
#        [ 1973.   ,   439.302],
#        [ 1974.   ,   452.744],
#        [ 1974.   ,   242.018],
#        [ 1974.   ,   495.114],
#        [ 1975.   ,   532.481],
#        [ 1975.   ,   363.61 ],
#        [ 1975.   ,   284.269],
#        [ 1975.   ,   560.75 ],
#        [ 1976.   ,   543.337],
#        [ 1976.   ,   591.098],
#        [ 1976.   ,   303.725],
#        [ 1976.   ,   638.851],
#        [ 1977.   ,   647.352],
#        [ 1977.   ,   340.628],
#        [ 1977.   ,   726.241],
# ...

# %%
X_mean = np.mean(X, 0)
X_std = np.std(X, 0)
X_normalized = (X - X_mean) / X_std

# %%
X_mean
# Out:
# array([1996.97482014, 2777.48482374])

# %%
X_std
# Out:
# array([  14.05600613, 2181.60680792])

# %%
X_normalized
# Out:
# array([[-1.91909564e+00, -1.15748347e+00],
#        [-1.91909564e+00, -1.18506314e+00],
#        [-1.91909564e+00, -1.21630159e+00],
#        [-1.91909564e+00, -1.20418025e+00],
#        [-1.91909564e+00, -1.12326557e+00],
#        [-1.84795168e+00, -1.12948576e+00],
#        [-1.84795168e+00, -1.13642560e+00],
#        [-1.84795168e+00, -1.21163576e+00],
#        [-1.84795168e+00, -1.19803019e+00],
#        [-1.84795168e+00, -1.10904349e+00],
#        [-1.77680772e+00, -1.11849707e+00],
#        [-1.77680772e+00, -1.18815857e+00],
#        [-1.77680772e+00, -1.09111679e+00],
#        [-1.70566375e+00, -1.09687218e+00],
#        [-1.70566375e+00, -1.17881316e+00],
#        [-1.70566375e+00, -1.07177096e+00],
#        [-1.63451979e+00, -1.06560945e+00],
#        [-1.63451979e+00, -1.16220155e+00],
#        [-1.63451979e+00, -1.04618798e+00],
#        [-1.56337582e+00, -1.02905978e+00],
#        [-1.56337582e+00, -1.10646649e+00],
#        [-1.56337582e+00, -1.14283464e+00],
# ...

# %%
def computeCost(X,y,theta):
    m=y.size
    h=X.dot(theta)
    J=1/(2*m)*np.sum((h-y)**2)
    return(J)

# %%
m = X_normalized.shape[0]
X_normalized = np.c_[np.ones(m), X_normalized]
computeCost(X_normalized,y,[[0],[0],[0]])
# Out:
# 3039.916960431655

# %%
def gradientDescent(X, y, theta, alpha=0.01, num_iters=50):
    m = y.size
    J_history = np.zeros(num_iters)
    for i in range(num_iters):
        h = X.dot(theta)
        gradient = (1/m) * X.T.dot(h - y)
        theta = theta - alpha * gradient        
        J_history[i] = computeCost(X, y, theta)
    return theta, J_history

# %%
# run gradient descent
theta1,cost_J1=gradientDescent(X_normalized,y,[[0],[0],[0]],1)
theta2,cost_J2=gradientDescent(X_normalized,y,[[0],[0],[0]],0.3)
theta3,cost_J3=gradientDescent(X_normalized,y,[[0],[0],[0]],0.1)
# plot
plt.plot(cost_J1,label='alpha=1')
plt.plot(cost_J2,label='alpha=0.4')
plt.plot(cost_J3,label='alpha=0.2')
plt.xlabel('Number of Iter')
plt.ylabel('Cost function')
plt.legend()

# %%
new_data = np.c_[2025, 8000]
# normalize
new_data_norm = (new_data - X_mean) / X_std
# predict
new_data_norm=np.c_[1, new_data_norm]
print(new_data_norm.dot(theta1))
# Out:
# [[82.47614652]]
